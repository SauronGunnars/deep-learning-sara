# %% [markdown]
# # Network Architecture Exploration: Understanding Underfitting and Overfitting
# ## Background
# This exercise aims to demonstrate how different neural network architectures can lead to underfitting or overfitting. You will experiment with various configurations of a fully connected neural network to observe these phenomena.
#
# ## Underfitting
# Occurs when a model is too simple to capture the underlying pattern of the data. Often caused by having too few layers or neurons.
#
# ## Overfitting
# Happens when a model learns the training data too well, including the noise, making it perform poorly on new, unseen data. This can result from having too many layers or neurons.

# %% [markdown]
# ## Setup
# Import the necessary libraries and prepare the dataset.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles

# Generate synthetic data
X, y = make_circles(n_samples=6000, noise=0.09, factor=0.5, random_state=42)

# Splitting the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# Visualize the dataset
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=plt.cm.RdBu)
plt.title("Training Data")
plt.show()

# %% [markdown]
# # Model Building
# Define a function to create a model with a variable number of layers and neurons.

# %%
def build_model(num_layers=5, num_neurons=100, activation_function='sigmoid'):
    model = tf.keras.models.Sequential()
    
    model.add(tf.keras.layers.Dense(num_neurons, activation=activation_function, input_shape=(2,)))
    
    for _ in range(num_layers - 1):
        model.add(tf.keras.layers.Dense(num_neurons, activation=activation_function))
        
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# %% [markdown]
# # Train and Evaluate Model Script
# Below is a skeleton for a function to train and evaluate your models. Fill in the missing parts as indicated by the comments.

# %%
def train_and_evaluate_model(model, epochs=50, plot=True):
    # Train the model
    history = model.fit(X_train, y_train, epochs=epochs, verbose=0, validation_split=0.2)

    # Evaluate the model on the test set
    test_loss, test_accuracy =  model.evaluate(X_test, y_test, verbose = 0)

    # Track training and validation loss
    training_loss = history.history['loss']
    validation_loss = history.history['val_loss']

    # Plotting (if enabled)
    if plot:
        #plotting training history
        plt.figure(figsize=(12, 10))

        # Plot training and validation accuracy
        plt.subplot(2,2,1)
        plt.plot(history.history['accuracy'], label = 'Accuracy training data')
        plt.plot(history.history['val_accuracy'], label = 'Validation data')
        plt.title('Training and Validation Accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend()

        plt.subplot(2,2,2)
        plt.plot(training_loss, label='Training Loss')
        plt.plot(validation_loss, label='Validation Loss')
        plt.title('Training and Validation Loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend()

        # Plot model predictions vs. ground truth on the test set
        prediction = model.predict(X_test) > 0.5 

        plt.subplot(2,2,3)
        plt.scatter(X_test[:, 0], X_test[:, 1], c=prediction[:, 0], cmap=plt.cm.coolwarm)
        plt.title('Model Predictions on Test Data')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')

        plt.subplot(2, 2, 4)
        plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.coolwarm)
        plt.title('Ground Truth for Test Data')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')

        plt.show()

        print(f"Test Loss: {test_loss:.4f}")
        print(f"Test Accuracy: {test_accuracy:.4f}")

    

model = build_model(num_layers=5, num_neurons=100)

# %%
underfitting = train_and_evaluate_model(model, epochs=50)
# Out:
# 94/94 [==============================] - 0s 712us/step
# Test Loss: 0.6772
# Test Accuracy: 0.7327

# %%
overfitting = train_and_evaluate_model(model, epochs=50)
# Out:
# 94/94 [==============================] - 0s 893us/step
# Test Loss: 0.6946
# Test Accuracy: 0.5027

# %% [markdown]
# # Experimentation
# ## Task 1: Underfitting
# 1. Create and train a model with very few layers and/or neurons (e.g., 1 layer with 5 neurons).
# 2. Evaluate Performance:
#     * Plot training and validation accuracy over epochs.
#     * Plot model predictions vs. ground truth on the test data.
#     * Analyze if the model's performance is poor on both training and test data, which indicates underfitting.
# ## Task 2: Overfitting
# 1. Create a model with an excessive number of layers and/or neurons (e.g., 5 layers with 100 neurons each) and increased number of epochs.
# 2. Evaluate Performance:
#     * Observe the training and validation accuracy plots for a wide gap, indicating overfitting.
#     * Compare model predictions with ground truth for the test data.
#     * Look for high training accuracy but poor test accuracy.
# ## Task 3: Balanced Model
# 1. Experiment to find a balanced architecture.
# 2. Evaluate Performance:
#     * Ensure the training and validation accuracy are both high and close to each other.
#     * The model's predictions should closely match the ground truth for the test data.
#     * The model should not show signs of significant underfitting or overfitting.

# %% [markdown]
# # Evaluation and Analysis
# Use similar evaluation and visualization code as in the previous exercise to assess model performance.
# Answer questions like:
# 1. What signs of underfitting did you observe?
# 2. What were the indications of overfitting?
# 3. Describe the architecture of the balanced model and its performance.
#
# # Conclusion
# Reflect on the importance of matching model complexity with the problem complexity and discuss the trade-offs involved in designing neural network architectures.

# %% [markdown]
# ------------------

# %% [markdown]
# # Regularization Technique: Early Stopping
# ## Objective
# Understand how early stopping can be used as a regularization technique to prevent overfitting and improve the generalization of neural networks.
#
# ## Background
# Early stopping is a form of regularization used to avoid overfitting when training a learner with an iterative method, such as gradient descent. It involves stopping the training process if the model's performance on a validation set starts to deteriorate, meaning the model begins to learn noise and details from the training data that negatively impact its performance on unseen data.
#
# ## How Early Stopping Works
# * Monitor the model's performance on a validation set during training.
# * If the performance on the validation set stops improving or starts to worsen, stop the training.
# * Often, a 'patience' parameter is set to allow some leeway, meaning training will stop only after the model's performance hasn't improved for a specified number of epochs.

# %% [markdown]
# # Implementation in TensorFlow
# TensorFlow provides an easy way to implement early stopping through callbacks. Here’s how you can add early stopping to your training process:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Create an EarlyStopping callback instance
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Include this callback in the model's fit method
model.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0446 - accuracy: 0.9946 - val_loss: 0.0490 - val_accuracy: 0.9933
# Epoch 2/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0434 - accuracy: 0.9946 - val_loss: 0.0477 - val_accuracy: 0.9933
# Epoch 3/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0423 - accuracy: 0.9950 - val_loss: 0.0464 - val_accuracy: 0.9933
# Epoch 4/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0411 - accuracy: 0.9950 - val_loss: 0.0453 - val_accuracy: 0.9933
# Epoch 5/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9950 - val_loss: 0.0444 - val_accuracy: 0.9933
# Epoch 6/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0389 - accuracy: 0.9954 - val_loss: 0.0441 - val_accuracy: 0.9900
# Epoch 7/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9946 - val_loss: 0.0425 - val_accuracy: 0.9933
# Epoch 8/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9950 - val_loss: 0.0416 - val_accuracy: 0.9933
# Epoch 9/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0363 - accuracy: 0.9946 - val_loss: 0.0410 - val_accuracy: 0.9917
# Epoch 10/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0355 - accuracy: 0.9950 - val_loss: 0.0395 - val_accuracy: 0.9933
# Epoch 11/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0347 - accuracy: 0.9954 - val_loss: 0.0392 - val_accuracy: 0.9933
# Epoch 12/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0341 - accuracy: 0.9954 - val_loss: 0.0377 - val_accuracy: 0.9933
# Epoch 13/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0333 - accuracy: 0.9950 - val_loss: 0.0375 - val_accuracy: 0.9933
# Epoch 14/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0325 - accuracy: 0.9954 - val_loss: 0.0361 - val_accuracy: 0.9950
# Epoch 15/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0319 - accuracy: 0.9946 - val_loss: 0.0359 - val_accuracy: 0.9933
# Epoch 16/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.9946 - val_loss: 0.0353 - val_accuracy: 0.9933
# Epoch 17/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0307 - accuracy: 0.9950 - val_loss: 0.0343 - val_accuracy: 0.9933
# Epoch 18/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0299 - accuracy: 0.9954 - val_loss: 0.0347 - val_accuracy: 0.9917
# Epoch 19/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 0.9950 - val_loss: 0.0331 - val_accuracy: 0.9933
# Epoch 20/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0291 - accuracy: 0.9950 - val_loss: 0.0332 - val_accuracy: 0.9917
# Epoch 21/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0286 - accuracy: 0.9954 - val_loss: 0.0321 - val_accuracy: 0.9933
# Epoch 22/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 0.9954 - val_loss: 0.0317 - val_accuracy: 0.9933
# Epoch 23/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0273 - accuracy: 0.9958 - val_loss: 0.0322 - val_accuracy: 0.9917
# Epoch 24/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0271 - accuracy: 0.9950 - val_loss: 0.0309 - val_accuracy: 0.9917
# Epoch 25/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0266 - accuracy: 0.9950 - val_loss: 0.0305 - val_accuracy: 0.9917
# Epoch 26/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0261 - accuracy: 0.9962 - val_loss: 0.0296 - val_accuracy: 0.9933
# Epoch 27/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0259 - accuracy: 0.9958 - val_loss: 0.0291 - val_accuracy: 0.9933
# Epoch 28/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0255 - accuracy: 0.9958 - val_loss: 0.0287 - val_accuracy: 0.9933
# Epoch 29/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0252 - accuracy: 0.9954 - val_loss: 0.0291 - val_accuracy: 0.9917
# Epoch 30/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0247 - accuracy: 0.9958 - val_loss: 0.0289 - val_accuracy: 0.9917
# Epoch 31/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0243 - accuracy: 0.9950 - val_loss: 0.0284 - val_accuracy: 0.9917
# Epoch 32/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0241 - accuracy: 0.9950 - val_loss: 0.0281 - val_accuracy: 0.9917
# Epoch 33/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0237 - accuracy: 0.9950 - val_loss: 0.0269 - val_accuracy: 0.9933
# Epoch 34/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0233 - accuracy: 0.9954 - val_loss: 0.0266 - val_accuracy: 0.9933
# Epoch 35/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0230 - accuracy: 0.9958 - val_loss: 0.0262 - val_accuracy: 0.9933
# Epoch 36/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0226 - accuracy: 0.9954 - val_loss: 0.0271 - val_accuracy: 0.9917
# Epoch 37/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0226 - accuracy: 0.9946 - val_loss: 0.0264 - val_accuracy: 0.9917
# Epoch 38/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0222 - accuracy: 0.9954 - val_loss: 0.0254 - val_accuracy: 0.9933
# Epoch 39/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0219 - accuracy: 0.9954 - val_loss: 0.0253 - val_accuracy: 0.9917
# Epoch 40/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0216 - accuracy: 0.9958 - val_loss: 0.0249 - val_accuracy: 0.9933
# Epoch 41/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 0.9958 - val_loss: 0.0247 - val_accuracy: 0.9917
# Epoch 42/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0211 - accuracy: 0.9958 - val_loss: 0.0246 - val_accuracy: 0.9917
# Epoch 43/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0211 - accuracy: 0.9958 - val_loss: 0.0242 - val_accuracy: 0.9917
# Epoch 44/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9954 - val_loss: 0.0236 - val_accuracy: 0.9933
# Epoch 45/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0204 - accuracy: 0.9958 - val_loss: 0.0244 - val_accuracy: 0.9917
# Epoch 46/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0202 - accuracy: 0.9958 - val_loss: 0.0235 - val_accuracy: 0.9917
# Epoch 47/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 0.9962 - val_loss: 0.0232 - val_accuracy: 0.9933
# Epoch 48/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 0.9954 - val_loss: 0.0230 - val_accuracy: 0.9933
# Epoch 49/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9954 - val_loss: 0.0236 - val_accuracy: 0.9917
# Epoch 50/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9958 - val_loss: 0.0240 - val_accuracy: 0.9933
# Epoch 51/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9962 - val_loss: 0.0222 - val_accuracy: 0.9933
# Epoch 52/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9962 - val_loss: 0.0220 - val_accuracy: 0.9933
# Epoch 53/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9954 - val_loss: 0.0226 - val_accuracy: 0.9917
# Epoch 54/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9962 - val_loss: 0.0219 - val_accuracy: 0.9917
# Epoch 55/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9958 - val_loss: 0.0217 - val_accuracy: 0.9933
# Epoch 56/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9958 - val_loss: 0.0219 - val_accuracy: 0.9917
# Epoch 57/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9962 - val_loss: 0.0218 - val_accuracy: 0.9917
# Epoch 58/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0180 - accuracy: 0.9962 - val_loss: 0.0209 - val_accuracy: 0.9933
# Epoch 59/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0180 - accuracy: 0.9954 - val_loss: 0.0209 - val_accuracy: 0.9933
# Epoch 60/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.9958 - val_loss: 0.0216 - val_accuracy: 0.9917
# Epoch 61/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9958 - val_loss: 0.0212 - val_accuracy: 0.9917
# Epoch 62/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.9958 - val_loss: 0.0212 - val_accuracy: 0.9917
# Epoch 63/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9954 - val_loss: 0.0206 - val_accuracy: 0.9917
# Epoch 64/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9958 - val_loss: 0.0200 - val_accuracy: 0.9933
# Epoch 65/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9958 - val_loss: 0.0209 - val_accuracy: 0.9917
# Epoch 66/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 0.9962 - val_loss: 0.0196 - val_accuracy: 0.9933
# Epoch 67/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0169 - accuracy: 0.9954 - val_loss: 0.0207 - val_accuracy: 0.9917
# Epoch 68/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9962 - val_loss: 0.0207 - val_accuracy: 0.9917
# Epoch 69/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0166 - accuracy: 0.9962 - val_loss: 0.0194 - val_accuracy: 0.9933
# Epoch 70/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0167 - accuracy: 0.9958 - val_loss: 0.0191 - val_accuracy: 0.9933
# Epoch 71/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0164 - accuracy: 0.9954 - val_loss: 0.0201 - val_accuracy: 0.9917
# Epoch 72/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 0.9967 - val_loss: 0.0193 - val_accuracy: 0.9917
# Epoch 73/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 0.9958 - val_loss: 0.0188 - val_accuracy: 0.9933
# Epoch 74/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 0.9958 - val_loss: 0.0186 - val_accuracy: 0.9933
# Epoch 75/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0160 - accuracy: 0.9954 - val_loss: 0.0198 - val_accuracy: 0.9917
# Epoch 76/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0160 - accuracy: 0.9962 - val_loss: 0.0189 - val_accuracy: 0.9917
# Epoch 77/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0158 - accuracy: 0.9958 - val_loss: 0.0192 - val_accuracy: 0.9917
# Epoch 78/100
# 75/75 [==============================] - 0s 1ms/step - loss: 0.0157 - accuracy: 0.9971 - val_loss: 0.0181 - val_accuracy: 0.9933
# Epoch 79/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.0187 - val_accuracy: 0.9917
# Epoch 80/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.9967 - val_loss: 0.0191 - val_accuracy: 0.9917
# Epoch 81/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9962 - val_loss: 0.0183 - val_accuracy: 0.9917
# Epoch 82/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9958 - val_loss: 0.0185 - val_accuracy: 0.9917
# Epoch 83/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9962 - val_loss: 0.0189 - val_accuracy: 0.9917

# %% [markdown]
# ## Task
# 1. Add early stopping to your neural network training process using the above code snippet.
# 2. Experiment with different values for the patience parameter and observe how it impacts the training process and the model's performance.
#
# ## Analysis and Questions
# * How does early stopping affect the number of epochs for which your model trains?
# * Did you observe any improvements in the generalization of your model to the test data?
# * How does the patience parameter impact the effectiveness of early stopping?
#
# ## Conclusion
# Reflect on the importance of regularization techniques like early stopping in preventing overfitting and improving model generalization.
